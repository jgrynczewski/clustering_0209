# %% [markdown]
# ### Algorytm k-średnich

# %% [markdown]
# ![newplot (7).png](attachment:57fad4aa-afef-4b52-bb14-07a9e954a8ab.png)

# %% [markdown]
# ![newplot (8).png](attachment:900a6cb3-80d4-457b-9a13-ffcdeaf1353d.png)

# %% [markdown]
# ![newplot (9).png](attachment:c6c69253-adb3-48a7-a62f-720b761fc6cd.png)

# %% [markdown]
# ![newplot (10).png](attachment:f5a9b84d-e6e1-45f4-93c3-58a9f30a09ec.png)

# %% [markdown]
# ![newplot (11).png](attachment:a711abcf-cd7a-4226-af3c-357ec8d8c566.png)

# %% [markdown]
# ![newplot (12).png](attachment:b77aa8d3-c957-407a-8c42-41dd57d4159b.png)

# %% [markdown]
# ![newplot (13).png](attachment:3d6a0846-7722-400d-87e9-f4c0684b6443.png)

# %% [markdown]
# ![newplot (14).png](attachment:8d95f95c-ee3b-4fc0-a5d5-ace9dbf8ca4a.png)

# %% [markdown]
# ![newplot (15).png](attachment:159ca814-c2c9-4d2c-9f71-06b094b4a3d4.png)

# %% [markdown]
# ![newplot (16).png](attachment:1466860a-6c90-49cf-a11f-5248bad42940.png)

# %% [markdown]
# ![newplot (17).png](attachment:1d70c7ac-5b58-44f8-bc04-e23dbfe0d97b.png)

# %% [markdown]
# ![newplot (18).png](attachment:5e612f8c-81a2-4b25-9b7f-c582586a86bb.png)
