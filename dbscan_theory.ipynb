# %% [markdown]
# ### DBSCAN

# %% [markdown]
# Metoda gęstościowa

# %% [markdown]
# #### Dane

# %% [markdown]
# ![dbscan2a.png](attachment:0eb038cb-82e5-43e5-aea4-643f92be9a9d.png)

# %% [markdown]
# #### Podstawowe parametry

# %% [markdown]
# ![minimalna liczba punktow potrzebnych do zdefiniowania klastra.png](attachment:ebb14ee5-1eee-4cc9-840a-a6fc59fb1390.png)

# %% [markdown]
# #### Rodzaje punktów

# %% [markdown]
# ![DB0.png](attachment:60ed17c4-2f8b-4f1d-80e1-e3c80f009f71.png)

# %% [markdown]
# #### Algorytm

# %% [markdown]
# Punkty rdzeniowe

# %% [markdown]
# ![DB1.png](attachment:7091e944-78b0-4fc5-8dca-e412cade0d49.png)

# %% [markdown]
# ![DB2.png](attachment:bd4b5bc0-5e55-4872-a7fd-e1124b35e629.png)

# %% [markdown]
# ![DB4.png](attachment:79136add-35f5-4b19-a198-6d2f754015d3.png)

# %% [markdown]
# ![DB5.png](attachment:0fa28b01-d1da-418c-8652-5d650d719780.png)

# %% [markdown]
# ![DB6.png](attachment:cab3d872-0221-4bc9-a31b-d7cae6ec14a2.png)

# %% [markdown]
# ![DB7.png](attachment:e037cce9-0097-448b-aeb1-16fac9111bdd.png)

# %% [markdown]
# ![DB8.png](attachment:310a6bd0-5ad8-4f0e-a0a2-ad2c7cea03c6.png)

# %% [markdown]
# ![DB10.png](attachment:b4930025-d01b-43d2-a0da-062c8aff7779.png)

# %% [markdown]
# Punkty graniczne (w sąsiedztwie liczba punktów mniej niż min_sample) - z punktu granicznego, w odróżnieniu od punktów rdzeniowych nie jesteśmy w stanie pójść nigdzie dalej.

# %% [markdown]
# ![DB11.png](attachment:21dcaacd-d401-40fc-8b02-7b86f8eb30c2.png)

# %% [markdown]
# Outliery

# %% [markdown]
# Punkty, które nie są w stanie zainicjalizować klastra (ponieważ nie spełniają min_samples) są outlierami.

# %% [markdown]
# ![DB12.png](attachment:70614cfd-ad92-4043-a1ad-1bbcdfdb81cc.png)

# %% [markdown]
# ![DB13.png](attachment:745fdaf6-0016-409f-a730-9f01e41060e5.png)

# %% [markdown]
# Wynik

# %% [markdown]
# ![DB14.png](attachment:619392da-51e9-4ade-b627-b6a28577b96a.png)
